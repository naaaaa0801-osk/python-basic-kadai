# %%
class Human:
  def __init__(self,name,age):
    self.name=name
    self.age=age

  def check_adult(self):
    if self.age >= 20:
      print(f"{self.name}は大人です")
    else:
      print(f"{self.name}は大人ではありません")

Taro = Human ("太郎",21)
Hanako = Human ("花子",20)
Jiro = Human ("次郎",19)
Saburo = Human ("三郎",15)

family = [Taro,Hanako,Jiro,Saburo]

for info in family:
  info.check_adult();
# Out:
# 太郎は大人です
# 花子は大人です
# 次郎は大人ではありません
# 三郎は大人ではありません
