# %%
class Human:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name)
        print(self.age)

Taro = Human("太郎",5)
Taro.printinfo()
# Out:
# 太郎
# 5
